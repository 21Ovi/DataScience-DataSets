# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('https://raw.githubusercontent.com/21Ovi/DataScience-DataSets/main/pokemon.csv')

# %%
data
# Out:
#          id            identifier  species_id  height  weight  \
# 0         1             bulbasaur           1       7      69
# 1         2               ivysaur           2      10     130
# 2         3              venusaur           3      20    1000
# 3         4            charmander           4       6      85
# 4         5            charmeleon           5      11     190
# ...     ...                   ...         ...     ...     ...
# 1087  10190   eternatus-eternamax         890    1000       0
# 1088  10191  urshifu-rapid-strike         892      19    1050
# 1089  10192           zarude-dada         893      18     700
# 1090  10193           calyrex-ice         898      24    8091
# 1091  10194        calyrex-shadow         898      24     536
#
#       base_experience  order  is_default
# 0                  64      1           1
# 1                 142      2           1
# 2                 263      3           1
# 3                  62      5           1
# ...

# %%
data.head(100)
# Out:
#      id  identifier  species_id  height  weight  base_experience  order  \
# 0     1   bulbasaur           1       7      69               64      1
# 1     2     ivysaur           2      10     130              142      2
# 2     3    venusaur           3      20    1000              263      3
# 3     4  charmander           4       6      85               62      5
# 4     5  charmeleon           5      11     190              142      6
# ..  ...         ...         ...     ...     ...              ...    ...
# 95   96     drowzee          96      10     324               66    154
# 96   97       hypno          97      16     756              169    155
# 97   98      krabby          98       4      65               65    156
# 98   99     kingler          99      13     600              166    157
# 99  100     voltorb         100       5     104               66    158
#
#     is_default
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...

# %%
data.tail(100)
# Out:
#          id            identifier  species_id  height  weight  \
# 992   10095     pikachu-hoenn-cap          25       4      60
# 993   10096    pikachu-sinnoh-cap          25       4      60
# 994   10097     pikachu-unova-cap          25       4      60
# 995   10098     pikachu-kalos-cap          25       4      60
# 996   10099     pikachu-alola-cap          25       4      60
# ...     ...                   ...         ...     ...     ...
# 1087  10190   eternatus-eternamax         890    1000       0
# 1088  10191  urshifu-rapid-strike         892      19    1050
# 1089  10192           zarude-dada         893      18     700
# 1090  10193           calyrex-ice         898      24    8091
# 1091  10194        calyrex-shadow         898      24     536
#
#       base_experience  order  is_default
# 992               112     43           0
# 993               112     44           0
# 994               112     45           0
# 995               112     46           0
# ...

# %%
data.describe()
# Out:
#                  id   species_id       height       weight  base_experience  \
# count   1092.000000  1092.000000  1092.000000  1092.000000      1092.000000
# mean    2163.521978   444.038462    13.512821   698.147436       159.930403
# std     3696.937585   267.429521    32.877363  1301.541675        85.569375
# min        1.000000     1.000000     1.000000     0.000000        36.000000
# 25%      273.750000   208.750000     5.000000    85.000000        70.000000
# 50%      546.500000   443.500000    10.000000   289.000000       161.000000
# 75%      819.250000   685.250000    15.000000   700.000000       198.750000
# max    10194.000000   898.000000  1000.000000  9999.000000       635.000000
#
#              order   is_default
# count  1092.000000  1092.000000
# mean    546.500000     0.822344
# std     315.377552     0.382398
# min       1.000000     0.000000
# 25%     273.750000     1.000000
# 50%     546.500000     1.000000
# 75%     819.250000     1.000000
# ...

# %%
data.describe(include='O')
# Out:
#        identifier
# count        1092
# unique       1092
# top     bulbasaur
# freq            1

# %%
data.columns
# Out:
# Index(['id', 'identifier', 'species_id', 'height', 'weight', 'base_experience',
#        'order', 'is_default'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1092 entries, 0 to 1091
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1092 non-null   int64
#  1   identifier       1092 non-null   object
#  2   species_id       1092 non-null   int64
#  3   height           1092 non-null   int64
#  4   weight           1092 non-null   int64
#  5   base_experience  1092 non-null   int64
#  6   order            1092 non-null   int64
#  7   is_default       1092 non-null   int64
# dtypes: int64(7), object(1)
# memory usage: 68.4+ KB

# %%
data.head()
# Out:
#    id  identifier  species_id  height  weight  base_experience  order  \
# 0   1   bulbasaur           1       7      69               64      1
# 1   2     ivysaur           2      10     130              142      2
# 2   3    venusaur           3      20    1000              263      3
# 3   4  charmander           4       6      85               62      5
# 4   5  charmeleon           5      11     190              142      6
#
#    is_default
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
data.identifier
# Out:
# 0                  bulbasaur
# 1                    ivysaur
# 2                   venusaur
# 3                 charmander
# 4                 charmeleon
#                 ...
# 1087     eternatus-eternamax
# 1088    urshifu-rapid-strike
# 1089             zarude-dada
# 1090             calyrex-ice
# 1091          calyrex-shadow
# Name: identifier, Length: 1092, dtype: object

# %%
data.identifier.unique()
# Out:
# array(['bulbasaur', 'ivysaur', 'venusaur', ..., 'zarude-dada',
#        'calyrex-ice', 'calyrex-shadow'], dtype=object)

# %%
data.height.unique()
# Out:
# array([   7,   10,   20,    6,   11,   17,    5,   16,    3,   15,   12,
#          35,    4,    8,   13,    9,   14,    2,   19,   18,   88,   22,
#          65,   25,   21,   40,   23,   92,   52,   38,  145,   27,   62,
#          45,   70,   24,   54,   42,   37,   32,   33,    1,   26,   28,
#          29,   30,   58,   50,   39,   34,   55,   36,  200,   69,  105,
#          98,  108,  109,   82,   31,   75, 1000], dtype=int64)

# %%
data.height.value_counts()
# Out:
# 4       93
# 3       91
# 6       88
# 5       71
# 10      70
#         ..
# 37       1
# 54       1
# 52       1
# 70       1
# 1000     1
# Name: height, Length: 62, dtype: int64

# %%
data.weight.value_counts()
# Out:
# 60      23
# 3       20
# 400     18
# 10      12
# 280     11
#         ..
# 6830     1
# 3360     1
# 265      1
# 4200     1
# 536      1
# Name: weight, Length: 479, dtype: int64

# %%
data.value_counts('height')
# Out:
# height
# 4       93
# 3       91
# 6       88
# 5       71
# 10      70
#         ..
# 58       1
# 54       1
# 52       1
# 34       1
# 1000     1
# Length: 62, dtype: int64

# %%
data['identifier']
# Out:
# 0                  bulbasaur
# 1                    ivysaur
# 2                   venusaur
# 3                 charmander
# 4                 charmeleon
#                 ...
# 1087     eternatus-eternamax
# 1088    urshifu-rapid-strike
# 1089             zarude-dada
# 1090             calyrex-ice
# 1091          calyrex-shadow
# Name: identifier, Length: 1092, dtype: object

# %%
data[['identifier','base_experience','order']].tail()
# Out:
#                 identifier  base_experience  order
# 1087   eternatus-eternamax              563   1080
# 1088  urshifu-rapid-strike              275   1083
# 1089           zarude-dada              300   1085
# 1090           calyrex-ice              340   1091
# 1091        calyrex-shadow              340   1092

# %%
data[15:30]
# Out:
#     id identifier  species_id  height  weight  base_experience  order  \
# 15  16     pidgey          16       3      18               50     21
# 16  17  pidgeotto          17      11     300              122     22
# 17  18    pidgeot          18      15     395              216     23
# 18  19    rattata          19       3      35               51     25
# 19  20   raticate          20       7     185              145     27
# 20  21    spearow          21       3      20               52     30
# 21  22     fearow          22      12     380              155     31
# 22  23      ekans          23      20      69               58     32
# 23  24      arbok          24      35     650              157     33
# 24  25    pikachu          25       4      60              112     35
# 25  26     raichu          26       8     300              243     51
# 26  27  sandshrew          27       6     120               60     53
# ...

# %%
data.iloc[15:30,1:8]
# Out:
#    identifier  species_id  height  weight  base_experience  order  is_default
# 15     pidgey          16       3      18               50     21           1
# 16  pidgeotto          17      11     300              122     22           1
# 17    pidgeot          18      15     395              216     23           1
# 18    rattata          19       3      35               51     25           1
# 19   raticate          20       7     185              145     27           1
# 20    spearow          21       3      20               52     30           1
# 21     fearow          22      12     380              155     31           1
# 22      ekans          23      20      69               58     32           1
# 23      arbok          24      35     650              157     33           1
# 24    pikachu          25       4      60              112     35           1
# 25     raichu          26       8     300              243     51           1
# ...

# %%
data.iloc[15:30,1:4]
# Out:
#    identifier  species_id  height
# 15     pidgey          16       3
# 16  pidgeotto          17      11
# 17    pidgeot          18      15
# 18    rattata          19       3
# 19   raticate          20       7
# 20    spearow          21       3
# 21     fearow          22      12
# 22      ekans          23      20
# 23      arbok          24      35
# 24    pikachu          25       4
# 25     raichu          26       8
# 26  sandshrew          27       6
# 27  sandslash          28      10
# 28  nidoran-f          29       4
# 29   nidorina          30       8

# %%
data.loc[15:30,['identifier','height','weight']]
# Out:
#    identifier  height  weight
# 15     pidgey       3      18
# 16  pidgeotto      11     300
# 17    pidgeot      15     395
# 18    rattata       3      35
# 19   raticate       7     185
# 20    spearow       3      20
# 21     fearow      12     380
# 22      ekans      20      69
# 23      arbok      35     650
# 24    pikachu       4      60
# 25     raichu       8     300
# 26  sandshrew       6     120
# 27  sandslash      10     295
# 28  nidoran-f       4      70
# 29   nidorina       8     200
# 30  nidoqueen      13     600

# %%
data
# Out:
#          id            identifier  species_id  height  weight  \
# 0         1             bulbasaur           1       7      69
# 1         2               ivysaur           2      10     130
# 2         3              venusaur           3      20    1000
# 3         4            charmander           4       6      85
# 4         5            charmeleon           5      11     190
# ...     ...                   ...         ...     ...     ...
# 1087  10190   eternatus-eternamax         890    1000       0
# 1088  10191  urshifu-rapid-strike         892      19    1050
# 1089  10192           zarude-dada         893      18     700
# 1090  10193           calyrex-ice         898      24    8091
# 1091  10194        calyrex-shadow         898      24     536
#
#       base_experience  order  is_default
# 0                  64      1           1
# 1                 142      2           1
# 2                 263      3           1
# 3                  62      5           1
# ...

# %%
pd.set_option('display.max_rows',None)

# %%
data
# Out:
#          id                  identifier  species_id  height  weight  \
# 0         1                   bulbasaur           1       7      69
# 1         2                     ivysaur           2      10     130
# 2         3                    venusaur           3      20    1000
# 3         4                  charmander           4       6      85
# 4         5                  charmeleon           5      11     190
# 5         6                   charizard           6      17     905
# 6         7                    squirtle           7       5      90
# 7         8                   wartortle           8      10     225
# 8         9                   blastoise           9      16     855
# 9        10                    caterpie          10       3      29
# 10       11                     metapod          11       7      99
# 11       12                  butterfree          12      11     320
# 12       13                      weedle          13       3      32
# ...

# %%
pd.reset_option('display.max_rows',None)

# %%
data
# Out:
#          id            identifier  species_id  height  weight  \
# 0         1             bulbasaur           1       7      69
# 1         2               ivysaur           2      10     130
# 2         3              venusaur           3      20    1000
# 3         4            charmander           4       6      85
# 4         5            charmeleon           5      11     190
# ...     ...                   ...         ...     ...     ...
# 1087  10190   eternatus-eternamax         890    1000       0
# 1088  10191  urshifu-rapid-strike         892      19    1050
# 1089  10192           zarude-dada         893      18     700
# 1090  10193           calyrex-ice         898      24    8091
# 1091  10194        calyrex-shadow         898      24     536
#
#       base_experience  order  is_default
# 0                  64      1           1
# 1                 142      2           1
# 2                 263      3           1
# 3                  62      5           1
# ...

# %%
d1=data[['identifier','height','weight']]

# %%
d1
# Out:
#                 identifier  height  weight
# 0                bulbasaur       7      69
# 1                  ivysaur      10     130
# 2                 venusaur      20    1000
# 3               charmander       6      85
# 4               charmeleon      11     190
# ...                    ...     ...     ...
# 1087   eternatus-eternamax    1000       0
# 1088  urshifu-rapid-strike      19    1050
# 1089           zarude-dada      18     700
# 1090           calyrex-ice      24    8091
# 1091        calyrex-shadow      24     536
#
# [1092 rows x 3 columns]

# %%
data.loc[data['height'] == 21]
# Out:
#          id       identifier  species_id  height  weight  base_experience  \
# 142     143          snorlax         143      21    4600              189
# 225     226          mantine         226      21    2200              170
# 243     244            entei         244      21    1980              290
# 305     306           aggron         306      21    3600              265
# 603     604       eelektross         604      21     805              232
# 637     638         cobalion         638      21    2500              290
# 674     675          pangoro         675      21    1360              173
# 759     760           bewear         760      21    1350              175
# 811     812        rillaboom         812      21     900              265
# 857     858        hatterene         858      21      51              255
# 894     895        regidrago         895      21    2000              290
# 939   10042  aerodactyl-mega         142      21     790              215
# ...

# %%
data.loc[data['weight'] < 50]
# Out:
#          id           identifier  species_id  height  weight  base_experience  \
# 9        10             caterpie          10       3      29               39
# 12       13               weedle          13       3      32               39
# 15       16               pidgey          16       3      18               50
# 18       19              rattata          19       3      35               51
# 20       21              spearow          21       3      20               52
# ...     ...                  ...         ...     ...     ...              ...
# 1047  10150       ribombee-totem         743       4      20              162
# 1070  10173        corsola-galar         222       6       5              144
# 1076  10179         yamask-galar         562       5      15               61
# 1084  10187       morpeko-hangry         877       3      30              153
# 1087  10190  eternatus-eternamax         890    1000       0              563
#
#       order  is_default
# ...

# %%
data.loc[data['identifier'] == 'pikachu']
# Out:
#     id identifier  species_id  height  weight  base_experience  order  \
# 24  25    pikachu          25       4      60              112     35
#
#     is_default
# 24           1

# %%
data.loc[(data['height'] >= 21) & (data['weight'] < 70) & (data['base_experience'] > 18) & (data['is_default'] == 1)]
# Out:
#       id identifier  species_id  height  weight  base_experience  order  \
# 857  858  hatterene         858      21      51              255   1042
#
#      is_default
# 857           1

# %%
data.set_index('order',inplace=True)

# %%
data
# Out:
#           id            identifier  species_id  height  weight  \
# order
# 1          1             bulbasaur           1       7      69
# 2          2               ivysaur           2      10     130
# 3          3              venusaur           3      20    1000
# 5          4            charmander           4       6      85
# 6          5            charmeleon           5      11     190
# ...      ...                   ...         ...     ...     ...
# 1080   10190   eternatus-eternamax         890    1000       0
# 1083   10191  urshifu-rapid-strike         892      19    1050
# 1085   10192           zarude-dada         893      18     700
# 1091   10193           calyrex-ice         898      24    8091
# 1092   10194        calyrex-shadow         898      24     536
#
#        base_experience  is_default
# order
# 1                   64           1
# 2                  142           1
# 3                  263           1
# 5                   62           1
# ...

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#       order     id            identifier  species_id  height  weight  \
# 0         1      1             bulbasaur           1       7      69
# 1         2      2               ivysaur           2      10     130
# 2         3      3              venusaur           3      20    1000
# 3         5      4            charmander           4       6      85
# 4         6      5            charmeleon           5      11     190
# ...     ...    ...                   ...         ...     ...     ...
# 1087   1080  10190   eternatus-eternamax         890    1000       0
# 1088   1083  10191  urshifu-rapid-strike         892      19    1050
# 1089   1085  10192           zarude-dada         893      18     700
# 1090   1091  10193           calyrex-ice         898      24    8091
# 1091   1092  10194        calyrex-shadow         898      24     536
#
#       base_experience  is_default
# 0                  64           1
# 1                 142           1
# ...

# %%
data['test'] = 'test'

# %%
data
# Out:
#       order     id            identifier  species_id  height  weight  \
# 0         1      1             bulbasaur           1       7      69
# 1         2      2               ivysaur           2      10     130
# 2         3      3              venusaur           3      20    1000
# 3         5      4            charmander           4       6      85
# 4         6      5            charmeleon           5      11     190
# ...     ...    ...                   ...         ...     ...     ...
# 1087   1080  10190   eternatus-eternamax         890    1000       0
# 1088   1083  10191  urshifu-rapid-strike         892      19    1050
# 1089   1085  10192           zarude-dada         893      18     700
# 1090   1091  10193           calyrex-ice         898      24    8091
# 1091   1092  10194        calyrex-shadow         898      24     536
#
#       base_experience  is_default  test
# 0                  64           1  test
# 1                 142           1  test
# ...

# %%
data.drop(['test'],axis=1)
# Out:
#       order     id            identifier  species_id  height  weight  \
# 0         1      1             bulbasaur           1       7      69
# 1         2      2               ivysaur           2      10     130
# 2         3      3              venusaur           3      20    1000
# 3         5      4            charmander           4       6      85
# 4         6      5            charmeleon           5      11     190
# ...     ...    ...                   ...         ...     ...     ...
# 1087   1080  10190   eternatus-eternamax         890    1000       0
# 1088   1083  10191  urshifu-rapid-strike         892      19    1050
# 1089   1085  10192           zarude-dada         893      18     700
# 1090   1091  10193           calyrex-ice         898      24    8091
# 1091   1092  10194        calyrex-shadow         898      24     536
#
#       base_experience  is_default
# 0                  64           1
# 1                 142           1
# ...

# %%
data.drop(1)
# Out:
#       order     id            identifier  species_id  height  weight  \
# 0         1      1             bulbasaur           1       7      69
# 2         3      3              venusaur           3      20    1000
# 3         5      4            charmander           4       6      85
# 4         6      5            charmeleon           5      11     190
# 5         7      6             charizard           6      17     905
# ...     ...    ...                   ...         ...     ...     ...
# 1087   1080  10190   eternatus-eternamax         890    1000       0
# 1088   1083  10191  urshifu-rapid-strike         892      19    1050
# 1089   1085  10192           zarude-dada         893      18     700
# 1090   1091  10193           calyrex-ice         898      24    8091
# 1091   1092  10194        calyrex-shadow         898      24     536
#
#       base_experience  is_default  test
# 0                  64           1  test
# 2                 263           1  test
# ...
