# %%
import pandas as pd
import numpy as np
import ssl

# %%
ssl._create_default_https_context = ssl._create_unverified_context

# %%
d1=pd.read_csv('ex1.csv')

# %%
d1
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
d1=pd.read_csv('ex1.csv',header=None)

# %%
d1
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
pwd
# Out:
# 'C:\\Users\\Ovesh-pc\\Downloads\\Examples for file reading-02-20220316T044539Z-001\\Examples for file reading-02'

# %%
d2=pd.read_csv("C:/Users/Ovesh-pc/Downloads/Examples for file reading-02-20220316T044539Z-001/Examples for file reading-02/ex1.csv")

# %%
d4 = pd.read_csv("C:/Users/Ovesh-pc/OneDrive/Desktop/ex1.csv")

# %%
d4
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
d5 = pd.read_table('test.tsv')

# %%
d5
# Out:
#             test     test   test.1   test.2   test.3
# Data        Data     Data     Data     Data     Data
# Science  Science  Science  Science  Science  Science

# %%
d5 = pd.read_csv('test.tsv',sep='\t') #Sep means sepeartion done by '\t' means tab
d5
# Out:
#             test     test   test.1   test.2   test.3
# Data        Data     Data     Data     Data     Data
# Science  Science  Science  Science  Science  Science

# %%
d6 = pd.read_csv('ex7.csv',sep='*')
d6
# Out:
#    a  b  c
# 0  1  2  3
# 1  1  2  3

# %%
type(d6)
# Out:
# pandas.core.frame.DataFrame

# %%
d1
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
d1.head(2)
# Out:
#    0  1  2  3        4
# 0  a  b  c  d  message
# 1  1  2  3  4    hello

# %%
d1.tail(2)
# Out:
#    0   1   2   3      4
# 2  5   6   7   8  world
# 3  9  10  11  12    foo

# %%
d7 = pd.read_csv('csv_mindex.csv')
d7
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10
# 5  two    b      11      12
# 6  two    c      13      14
# 7  two    d      15      16

# %%
d7 = pd.read_csv('csv_mindex.csv',index_col=['key1','key2'])
d7
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
d8 = pd.read_csv('ex5.csv')
d8
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
d8.isnull()
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %%
d8.isnull().sum()
# Out:
# something    0
# a            0
# b            0
# c            1
# d            0
# message      1
# dtype: int64

# %%
d9 = pd.read_csv('ex5.csv',na_values=['three'])
d9
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2       NaN  9  10  11.0  12     foo

# %%
d10 = pd.read_csv('junk.csv')
d10
# Out:
#   something  a  b     c   d message
# 0       one  1  2   3.0   4     NaN
# 1       two  $  6   NaN   8   world
# 2     three  9  $  11.0  12       *

# %%
junkChars = ['$','*','!','one']

# %%
d10 = pd.read_csv('junk.csv',na_values=junkChars)
d10
# Out:
#   something    a    b     c   d message
# 0       NaN  1.0  2.0   3.0   4     NaN
# 1       two  NaN  6.0   NaN   8   world
# 2     three  9.0  NaN  11.0  12     NaN

# %%
d10.isnull().sum()
# Out:
# something    1
# a            1
# b            1
# c            1
# d            0
# message      2
# dtype: int64

# %%
d11 = pd.read_excel('ex1.xlsx')
d11
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
d12 = pd.read_excel('ex1.xlsx',sheet_name='XYA')
d12
# Out:
#    1  2  3  3.1
# 0  4  5  6    9
# 1  7  8  5    2

# %%
pwd
# Out:
# 'C:\\Users\\Ovesh-pc\\Downloads\\Examples for file reading-02-20220316T044539Z-001\\Examples for file reading-02'

# %%
d1=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015.html')

# %%
d1
# Out:
# [      Eastern Conference                   W                   L  \
#  0      Atlantic Division   Atlantic Division   Atlantic Division
#  1       Toronto Raptors*                  49                  33
#  2        Boston Celtics*                  40                  42
#  3         Brooklyn Nets*                  38                  44
#  4     Philadelphia 76ers                  18                  64
#  5        New York Knicks                  17                  65
#  6       Central Division    Central Division    Central Division
#  7   Cleveland Cavaliers*                  53                  29
#  8         Chicago Bulls*                  50                  32
#  9       Milwaukee Bucks*                  41                  41
#  10        Indiana Pacers                  38                  44
#  11       Detroit Pistons                  32                  50
#  12    Southeast Division  Southeast Division  Southeast Division
# ...

# %%
d2=d1[0]

# %%
d2
# Out:
#       Eastern Conference                   W                   L  \
# 0      Atlantic Division   Atlantic Division   Atlantic Division
# 1       Toronto Raptors*                  49                  33
# 2        Boston Celtics*                  40                  42
# 3         Brooklyn Nets*                  38                  44
# 4     Philadelphia 76ers                  18                  64
# 5        New York Knicks                  17                  65
# 6       Central Division    Central Division    Central Division
# 7   Cleveland Cavaliers*                  53                  29
# 8         Chicago Bulls*                  50                  32
# 9       Milwaukee Bucks*                  41                  41
# 10        Indiana Pacers                  38                  44
# 11       Detroit Pistons                  32                  50
# 12    Southeast Division  Southeast Division  Southeast Division
# ...

# %%
d2=pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')

# %%
d2
# Out:
# [                         Bank NameBank           CityCity StateSt  CertCert  \
#  0                    Almena State Bank             Almena      KS     15426
#  1           First City Bank of Florida  Fort Walton Beach      FL     16748
#  2                 The First State Bank      Barboursville      WV     14361
#  3                   Ericson State Bank            Ericson      NE     18265
#  4     City National Bank of New Jersey             Newark      NJ     21111
#  ..                                 ...                ...     ...       ...
#  558                 Superior Bank, FSB           Hinsdale      IL     32646
#  559                Malta National Bank              Malta      OH      6629
#  560    First Alliance Bank & Trust Co.         Manchester      NH     34264
#  561  National State Bank of Metropolis         Metropolis      IL      3815
#  562                   Bank of Honolulu           Honolulu      HI     21029
#
# ...

# %%
# !pip install certifi

# %%
d2.to_csv('score.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17232/4133569526.py in <module>
# ----> 1 d2.to_csv('score.csv')
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %%
d3 = d1[9]
d3.to_csv('score1.csv')

# %%
d3 = pd.read_json('example.json')
d3
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
data = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.head(100)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %%
data.tail(145)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 746          747         0       3               Abbott, Mr. Rossmore Edward
# 747          748         1       2                     Sinkkonen, Miss. Anna
# 748          749         0       1                 Marvin, Mr. Daniel Warner
# 749          750         0       3                   Connaghton, Mr. Michael
# 750          751         1       2                         Wells, Miss. Joan
# ..           ...       ...     ...                                       ...
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
data.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.describe(include='O')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
data.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
data.Survived.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
data.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
data.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
data.Cabin.value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %%
data.value_counts("Sex")
# Out:
# Sex
# male      577
# female    314
# dtype: int64

# %%
data.value_counts("Survived")
# Out:
# Survived
# 0    549
# 1    342
# dtype: int64

# %%
data['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
data[['Survived','Name','Age','Sex']]
# Out:
#      Survived                                               Name   Age     Sex
# 0           0                            Braund, Mr. Owen Harris  22.0    male
# 1           1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2           1                             Heikkinen, Miss. Laina  26.0  female
# 3           1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4           0                           Allen, Mr. William Henry  35.0    male
# ..        ...                                                ...   ...     ...
# 886         0                              Montvila, Rev. Juozas  27.0    male
# 887         1                       Graham, Miss. Margaret Edith  19.0  female
# 888         0           Johnston, Miss. Catherine Helen "Carrie"   NaN  female
# 889         1                              Behr, Mr. Karl Howell  26.0    male
# 890         0                                Dooley, Mr. Patrick  32.0    male
#
# [891 rows x 4 columns]

# %%
data[15:30]
# Out:
#     PassengerId  Survived  Pclass  \
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ...

# %%
# Getting specific rows and columns using iloc function
data.iloc[15:30,1:8]
# Out:
#     Survived  Pclass                                               Name  \
# 15         1       2                   Hewlett, Mrs. (Mary D Kingcome)
# 16         0       3                               Rice, Master. Eugene
# 17         1       2                       Williams, Mr. Charles Eugene
# 18         0       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 19         1       3                            Masselmani, Mrs. Fatima
# 20         0       2                               Fynney, Mr. Joseph J
# 21         1       2                              Beesley, Mr. Lawrence
# 22         1       3                        McGowan, Miss. Anna "Annie"
# 23         1       1                       Sloper, Mr. William Thompson
# 24         0       3                      Palsson, Miss. Torborg Danira
# 25         1       3  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 26         0       3                            Emir, Mr. Farred Chehab
# ...

# %%
data.iloc[15:30,1:4]
# Out:
#     Survived  Pclass                                               Name
# 15         1       2                   Hewlett, Mrs. (Mary D Kingcome)
# 16         0       3                               Rice, Master. Eugene
# 17         1       2                       Williams, Mr. Charles Eugene
# 18         0       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 19         1       3                            Masselmani, Mrs. Fatima
# 20         0       2                               Fynney, Mr. Joseph J
# 21         1       2                              Beesley, Mr. Lawrence
# 22         1       3                        McGowan, Miss. Anna "Annie"
# 23         1       1                       Sloper, Mr. William Thompson
# 24         0       3                      Palsson, Miss. Torborg Danira
# 25         1       3  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 26         0       3                            Emir, Mr. Farred Chehab
# ...

# %%
data.loc[15:30,['Survived','Sex','Age']]
# Out:
#     Survived     Sex   Age
# 15         1  female  55.0
# 16         0    male   2.0
# 17         1    male   NaN
# 18         0  female  31.0
# 19         1  female   NaN
# 20         0    male  35.0
# 21         1    male  34.0
# 22         1  female  15.0
# 23         1    male  28.0
# 24         0  female   8.0
# 25         1  female  38.0
# 26         0    male   NaN
# 27         0    male  19.0
# 28         1  female   NaN
# 29         0    male   NaN
# 30         0    male  40.0

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.set_option('display.max_rows',None)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
pd.reset_option('display.max_rows',None)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
d1=data[['Survived','Age','Sex']]

# %%
d1
# Out:
#      Survived   Age     Sex
# 0           0  22.0    male
# 1           1  38.0  female
# 2           1  26.0  female
# 3           1  35.0  female
# 4           0  35.0    male
# ..        ...   ...     ...
# 886         0  27.0    male
# 887         1  19.0  female
# 888         0   NaN  female
# 889         1  26.0    male
# 890         0  32.0    male
#
# [891 rows x 3 columns]

# %%
data.loc[data['Sex'] == 'female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.loc[data['Age'] > 50]
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 54            55         0       1
# ..           ...       ...     ...
# 820          821         1       1
# 829          830         1       1
# 851          852         0       3
# 857          858         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 33                               Wheadon, Mr. Edward H    male  66.0      0
# 54                      Ostby, Mr. Engelhart Cornelius    male  65.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.loc[(data['Sex'] == 'female') & (data['Age'] < 38) & (data['Age'] > 18) & (data['Survived'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 44            45         1       3
# 53            54         1       2
# ..           ...       ...     ...
# 858          859         1       3
# 866          867         1       2
# 874          875         1       2
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 44                       Devaney, Miss. Margaret Delia  female  19.0      0
# 53   Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...  female  29.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.set_index('Sex',inplace=True)

# %%
data
# Out:
#         PassengerId  Survived  Pclass  \
# Sex
# male              1         0       3
# female            2         1       1
# female            3         1       3
# female            4         1       1
# male              5         0       3
# ...             ...       ...     ...
# male            887         0       2
# female          888         1       1
# female          889         0       3
# male            890         1       1
# male            891         0       3
#
#                                                      Name   Age  SibSp  Parch  \
# Sex
# male                              Braund, Mr. Owen Harris  22.0      1      0
# female  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# female                             Heikkinen, Miss. Laina  26.0      0      0
# female       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# male                             Allen, Mr. William Henry  35.0      0      0
# ...

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#         Sex  PassengerId  Survived  Pclass  \
# 0      male            1         0       3
# 1    female            2         1       1
# 2    female            3         1       3
# 3    female            4         1       1
# 4      male            5         0       3
# ..      ...          ...       ...     ...
# 886    male          887         0       2
# 887  female          888         1       1
# 888  female          889         0       3
# 889    male          890         1       1
# 890    male          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# ...

# %%
data['DS'] = 'Data Science'

# %%
data
# Out:
#         Sex  PassengerId  Survived  Pclass  \
# 0      male            1         0       3
# 1    female            2         1       1
# 2    female            3         1       3
# 3    female            4         1       1
# 4      male            5         0       3
# ..      ...          ...       ...     ...
# 886    male          887         0       2
# 887  female          888         1       1
# 888  female          889         0       3
# 889    male          890         1       1
# 890    male          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# ...

# %%
data.drop(['DS','Age'],axis=1)
# Out:
#         Sex  PassengerId  Survived  Pclass  \
# 0      male            1         0       3
# 1    female            2         1       1
# 2    female            3         1       3
# 3    female            4         1       1
# 4      male            5         0       3
# ..      ...          ...       ...     ...
# 886    male          887         0       2
# 887  female          888         1       1
# 888  female          889         0       3
# 889    male          890         1       1
# 890    male          891         0       3
#
#                                                   Name  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      1      0
# 2                               Heikkinen, Miss. Laina      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      1      0
# 4                             Allen, Mr. William Henry      0      0
# ...

# %%
data.drop('PassengerId',axis=1)
# Out:
#         Sex  Survived  Pclass  \
# 0      male         0       3
# 1    female         1       1
# 2    female         1       3
# 3    female         1       1
# 4      male         0       3
# ..      ...       ...     ...
# 886    male         0       2
# 887  female         1       1
# 888  female         0       3
# 889    male         1       1
# 890    male         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
data.drop(['DS','Age'],axis=1)
# Out:
#         Sex  PassengerId  Survived  Pclass  \
# 0      male            1         0       3
# 1    female            2         1       1
# 2    female            3         1       3
# 3    female            4         1       1
# 4      male            5         0       3
# ..      ...          ...       ...     ...
# 886    male          887         0       2
# 887  female          888         1       1
# 888  female          889         0       3
# 889    male          890         1       1
# 890    male          891         0       3
#
#                                                   Name  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      1      0
# 2                               Heikkinen, Miss. Laina      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      1      0
# 4                             Allen, Mr. William Henry      0      0
# ...

# %%
data.drop(1,axis=0)
# Out:
#         Sex  PassengerId  Survived  Pclass  \
# 0      male            1         0       3
# 2    female            3         1       3
# 3    female            4         1       1
# 4      male            5         0       3
# 5      male            6         0       3
# ..      ...          ...       ...     ...
# 886    male          887         0       2
# 887  female          888         1       1
# 888  female          889         0       3
# 889    male          890         1       1
# 890    male          891         0       3
#
#                                              Name   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris  22.0      1      0
# 2                          Heikkinen, Miss. Laina  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                        Allen, Mr. William Henry  35.0      0      0
# 5                                Moran, Mr. James   NaN      0      0
# ...

# %%
num = np.arange(1,100,10)
num
data.drop(num,axis=0)
# Out:
#         Sex  PassengerId  Survived  Pclass  \
# 0      male            1         0       3
# 2    female            3         1       3
# 3    female            4         1       1
# 4      male            5         0       3
# 5      male            6         0       3
# ..      ...          ...       ...     ...
# 886    male          887         0       2
# 887  female          888         1       1
# 888  female          889         0       3
# 889    male          890         1       1
# 890    male          891         0       3
#
#                                              Name   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris  22.0      1      0
# 2                          Heikkinen, Miss. Laina  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                        Allen, Mr. William Henry  35.0      0      0
# 5                                Moran, Mr. James   NaN      0      0
# ...
